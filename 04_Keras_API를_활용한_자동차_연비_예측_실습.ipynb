# %% [markdown]
# <a href="https://colab.research.google.com/github/YeolGwang/openknowl-TEST/blob/main/04_Keras_API%EB%A5%BC_%ED%99%9C%EC%9A%A9%ED%95%9C_%EC%9E%90%EB%8F%99%EC%B0%A8_%EC%97%B0%EB%B9%84_%EC%98%88%EC%B8%A1_%EC%8B%A4%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## DNN(MLP) 모델을 이용한 자동차 연비 데이터 셋 회귀 분석

# %%
import matplotlib.pyplot as plt
import pandas as pd

import tensorflow as tf
from tensorflow.keras import layers, models

# %%
print(tf.__version__)
# Out:
# 2.8.2

# %% [markdown]
# ### Step 1-1. Inptu tensor 와 Target tensor 준비(훈련데이터)
# * 자동차 연비 데이터셋 파일 down

# %%
auto_mpg_dataset_url = "http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data"
dataset_path = tf.keras.utils.get_file("/content/auto-mpg.data", auto_mpg_dataset_url)
dataset_path
# Out:
# Downloading data from http://archive.ics.uci.edu/ml/machine-learning-databases/auto-mpg/auto-mpg.data
# 32768/30286 [================================] - 0s 5us/step
# 40960/30286 [========================================] - 0s 4us/step
# '/content/auto-mpg.data'

# %% [markdown]
# *  데이터 셋 파일을 읽어 Dataframe 객체 생성

# %%
# 자동차 연비 데이터 셋의 컬럼명
column_names = ['MPG','Cylinders','Displacement','Horsepower','Weight',
                'Acceleration', 'Model Year', 'Origin']

raw_dataset = pd.read_csv(dataset_path, names=column_names,
                          na_values='?', comment='\t',
                          sep=" ", skipinitialspace=True)

dataset = raw_dataset.copy()
dataset
# Out:
#       MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0    18.0          8         307.0       130.0  3504.0          12.0
# 1    15.0          8         350.0       165.0  3693.0          11.5
# 2    18.0          8         318.0       150.0  3436.0          11.0
# 3    16.0          8         304.0       150.0  3433.0          12.0
# 4    17.0          8         302.0       140.0  3449.0          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0  2790.0          15.6
# 394  44.0          4          97.0        52.0  2130.0          24.6
# 395  32.0          4         135.0        84.0  2295.0          11.6
# 396  28.0          4         120.0        79.0  2625.0          18.6
# 397  31.0          4         119.0        82.0  2720.0          19.4
#
#      Model Year  Origin
# 0            70       1
# 1            70       1
# 2            70       1
# 3            70       1
# 4            70       1
# ..          ...     ...
# 393          82       1
# 394          82       2
# 395          82       1
# 396          82       1
# 397          82       1
#
# [398 rows x 8 columns]

# %% [markdown]
# ### Step 1-2. 입력 데이터의 전처리
# * 데이터 셋 내의 NaN 값 제거

# %%
# 데이터 셋 내의 Nan 값 체크
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      6
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %%
# 데이터 셋 내 의 Nan 값 제거
dataset = dataset.dropna()

# %%
len(dataset)
# Out:
# 392

# %%
dataset.isna().sum()
# Out:
# MPG             0
# Cylinders       0
# Displacement    0
# Horsepower      0
# Weight          0
# Acceleration    0
# Model Year      0
# Origin          0
# dtype: int64

# %% [markdown]
# * 데이터셋 에서 20% 선택하여 test 데이터 셋으로 분할

# %%
train_dataset = dataset.sample(frac=0.8, random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
print(len(train_dataset))
print(len(test_dataset))
# Out:
# 314
# 78

# %% [markdown]
# * 표준화를 통한 Input tensor의 전처리

# %%
# 데이터 전처리를 위한 통계정보 생성
train_stats = train_dataset.describe()

# %%
train_stats
# Out:
#               MPG   Cylinders  Displacement  Horsepower       Weight  \
# count  314.000000  314.000000    314.000000  314.000000   314.000000
# mean    23.310510    5.477707    195.318471  104.869427  2990.251592
# std      7.728652    1.699788    104.331589   38.096214   843.898596
# min     10.000000    3.000000     68.000000   46.000000  1649.000000
# 25%     17.000000    4.000000    105.500000   76.250000  2256.500000
# 50%     22.000000    4.000000    151.000000   94.500000  2822.500000
# 75%     28.950000    8.000000    265.750000  128.000000  3608.000000
# max     46.600000    8.000000    455.000000  225.000000  5140.000000
#
#        Acceleration  Model Year      Origin
# count    314.000000  314.000000  314.000000
# mean      15.559236   75.898089    1.573248
# std        2.789230    3.675642    0.800988
# min        8.000000   70.000000    1.000000
# 25%       13.800000   73.000000    1.000000
# 50%       15.500000   76.000000    1.000000
# 75%       17.200000   79.000000    2.000000
# max       24.800000   82.000000    3.000000

# %%
# 정답 데이터(MPG-연비) 제거
train_stats.pop('MPG')
# Out:
# count    314.000000
# mean      23.310510
# std        7.728652
# min       10.000000
# 25%       17.000000
# 50%       22.000000
# 75%       28.950000
# max       46.600000
# Name: MPG, dtype: float64

# %%
train_stats
# Out:
#         Cylinders  Displacement  Horsepower       Weight  Acceleration  \
# count  314.000000    314.000000  314.000000   314.000000    314.000000
# mean     5.477707    195.318471  104.869427  2990.251592     15.559236
# std      1.699788    104.331589   38.096214   843.898596      2.789230
# min      3.000000     68.000000   46.000000  1649.000000      8.000000
# 25%      4.000000    105.500000   76.250000  2256.500000     13.800000
# 50%      4.000000    151.000000   94.500000  2822.500000     15.500000
# 75%      8.000000    265.750000  128.000000  3608.000000     17.200000
# max      8.000000    455.000000  225.000000  5140.000000     24.800000
#
#        Model Year      Origin
# count  314.000000  314.000000
# mean    75.898089    1.573248
# std      3.675642    0.800988
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
# 각 특성 별 통계정보를 가공하기 쉽도록 matrix 전치
train_stats = train_stats.transpose()

# %%
train_stats
# Out:
#               count         mean         std     min      25%     50%  \
# Cylinders     314.0     5.477707    1.699788     3.0     4.00     4.0
# Displacement  314.0   195.318471  104.331589    68.0   105.50   151.0
# Horsepower    314.0   104.869427   38.096214    46.0    76.25    94.5
# Weight        314.0  2990.251592  843.898596  1649.0  2256.50  2822.5
# Acceleration  314.0    15.559236    2.789230     8.0    13.80    15.5
# Model Year    314.0    75.898089    3.675642    70.0    73.00    76.0
# Origin        314.0     1.573248    0.800988     1.0     1.00     1.0
#
#                   75%     max
# Cylinders        8.00     8.0
# Displacement   265.75   455.0
# Horsepower     128.00   225.0
# Weight        3608.00  5140.0
# Acceleration    17.20    24.8
# Model Year      79.00    82.0
# Origin           2.00     3.0

# %%
# Target tensor 를 위한 연비 값(MPG - Miles Per Gallon) 추출
train_labels = train_dataset.pop('MPG')
test_labels = test_dataset.pop('MPG')

# %%
train_dataset
# Out:
#      Cylinders  Displacement  Horsepower  Weight  Acceleration  Model Year  \
# 146          4          90.0        75.0  2125.0          14.5          74
# 282          4         140.0        88.0  2890.0          17.3          79
# 69           8         350.0       160.0  4456.0          13.5          72
# 378          4         105.0        63.0  2125.0          14.7          82
# 331          4          97.0        67.0  2145.0          18.0          80
# ..         ...           ...         ...     ...           ...         ...
# 281          6         200.0        85.0  2990.0          18.2          79
# 229          8         400.0       180.0  4220.0          11.1          77
# 150          4         108.0        93.0  2391.0          15.5          74
# 145          4          83.0        61.0  2003.0          19.0          74
# 182          4         107.0        86.0  2464.0          15.5          76
#
#      Origin
# 146       1
# 282       1
# 69        1
# 378       1
# 331       3
# ..      ...
# 281       1
# 229       1
# 150       3
# 145       3
# 182       2
#
# [314 rows x 7 columns]

# %%
# Input tensor의 표준화(평균 :0/ 표준편차 :1) 함수 정의
def norm(x):
  normed_data = (x - train_stats['mean']) / train_stats['std']
  return normed_data

# %%
# Input tensor 의 특성 정보 표준화 처리 수행
train_dataset = norm(train_dataset)
test_dataset = norm(test_dataset)

# %%
train_dataset.describe()
# Out:
#           Cylinders  Displacement    Horsepower        Weight  Acceleration  \
# count  3.140000e+02  3.140000e+02  3.140000e+02  3.140000e+02  3.140000e+02
# mean   1.824443e-16  8.627211e-17 -9.900078e-18 -8.485781e-17 -5.148041e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -1.457657e+00 -1.220325e+00 -1.545283e+00 -1.589352e+00 -2.710152e+00
# 25%   -8.693480e-01 -8.608943e-01 -7.512407e-01 -8.694784e-01 -6.307245e-01
# 50%   -8.693480e-01 -4.247848e-01 -2.721905e-01 -1.987817e-01 -2.123729e-02
# 75%    1.483887e+00  6.750739e-01  6.071620e-01  7.320173e-01  5.882500e-01
# max    1.483887e+00  2.489002e+00  3.153347e+00  2.547401e+00  3.313017e+00
#
#          Model Year        Origin
# count  3.140000e+02  3.140000e+02
# mean   9.772791e-16 -9.617219e-17
# std    1.000000e+00  1.000000e+00
# min   -1.604642e+00 -7.156763e-01
# 25%   -7.884578e-01 -7.156763e-01
# 50%    2.772599e-02 -7.156763e-01
# 75%    8.439098e-01  5.327813e-01
# max    1.660094e+00  1.781239e+00

# %% [markdown]
# ### Step2. DNN(MLP) 모델 디자인

# %%
# hidden layer : 2개[64, 32], activation : relu
model = models.Sequential()
model.add(layers.Dense(units=64, activation='relu', input_shape=(len(train_dataset.keys()),)))
model.add(layers.Dense(units=32, activation='relu'))
model.add(layers.Dense(units=1))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                512
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 2,625
# Trainable params: 2,625
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Step 3. 모델의 학습 정보 설정

# %%
# loss : mean square error/ optimizer : rmsprop/ metric : mean absolute error
model.compile(loss='mse',
              optimizer='rmsprop',
              metrics=['mae'])

# %% [markdown]
# ### Step 4. 모델에 input, target 데이터 연결 후 학습

# %%
# batch size : 16, epochs : 100, validation data set percent : 20%
history = model.fit(
    x=train_dataset, y=train_labels,
    batch_size=16,
    epochs=100,
    validation_split=0.2
)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 3s 13ms/step - loss: 568.9729 - mae: 22.6373 - val_loss: 562.7735 - val_mae: 22.4777
# Epoch 2/100
# 16/16 [==============================] - 0s 5ms/step - loss: 515.7125 - mae: 21.4763 - val_loss: 499.8894 - val_mae: 21.1107
# Epoch 3/100
# 16/16 [==============================] - 0s 4ms/step - loss: 454.4783 - mae: 20.0919 - val_loss: 426.3336 - val_mae: 19.4171
# Epoch 4/100
# 16/16 [==============================] - 0s 6ms/step - loss: 382.3865 - mae: 18.3550 - val_loss: 343.6692 - val_mae: 17.2832
# Epoch 5/100
# 16/16 [==============================] - 0s 4ms/step - loss: 303.4034 - mae: 16.1894 - val_loss: 256.6598 - val_mae: 14.6963
# Epoch 6/100
# 16/16 [==============================] - 0s 4ms/step - loss: 225.8540 - mae: 13.6982 - val_loss: 179.5357 - val_mae: 11.9411
# Epoch 7/100
# 16/16 [==============================] - 0s 4ms/step - loss: 155.8027 - mae: 11.0636 - val_loss: 114.3342 - val_mae: 9.1819
# Epoch 8/100
# 16/16 [==============================] - 0s 5ms/step - loss: 102.4900 - mae: 8.5508 - val_loss: 75.2200 - val_mae: 7.3366
# Epoch 9/100
# 16/16 [==============================] - 0s 4ms/step - loss: 71.1474 - mae: 6.7669 - val_loss: 57.6429 - val_mae: 6.3597
# Epoch 10/100
# 16/16 [==============================] - 0s 4ms/step - loss: 56.1341 - mae: 6.0077 - val_loss: 50.8023 - val_mae: 5.9946
# Epoch 11/100
# 16/16 [==============================] - 0s 4ms/step - loss: 47.3822 - mae: 5.4824 - val_loss: 46.1007 - val_mae: 5.6438
# Epoch 12/100
# 16/16 [==============================] - 0s 4ms/step - loss: 40.4806 - mae: 5.0441 - val_loss: 39.0503 - val_mae: 5.1227
# Epoch 13/100
# 16/16 [==============================] - 0s 5ms/step - loss: 33.9474 - mae: 4.5743 - val_loss: 33.5208 - val_mae: 4.6847
# Epoch 14/100
# 16/16 [==============================] - 0s 4ms/step - loss: 28.7083 - mae: 4.1931 - val_loss: 29.2683 - val_mae: 4.3368
# Epoch 15/100
# 16/16 [==============================] - 0s 5ms/step - loss: 24.3827 - mae: 3.8592 - val_loss: 24.8006 - val_mae: 3.9965
# Epoch 16/100
# 16/16 [==============================] - 0s 4ms/step - loss: 20.9877 - mae: 3.5613 - val_loss: 21.7433 - val_mae: 3.7076
# Epoch 17/100
# 16/16 [==============================] - 0s 4ms/step - loss: 18.4448 - mae: 3.3614 - val_loss: 19.0541 - val_mae: 3.5098
# Epoch 18/100
# 16/16 [==============================] - 0s 4ms/step - loss: 16.4338 - mae: 3.1242 - val_loss: 17.2166 - val_mae: 3.4859
# Epoch 19/100
# 16/16 [==============================] - 0s 5ms/step - loss: 14.5772 - mae: 2.9335 - val_loss: 15.1946 - val_mae: 3.2629
# Epoch 20/100
# 16/16 [==============================] - 0s 4ms/step - loss: 13.3648 - mae: 2.7718 - val_loss: 13.8206 - val_mae: 2.9686
# Epoch 21/100
# 16/16 [==============================] - 0s 4ms/step - loss: 12.2331 - mae: 2.6436 - val_loss: 12.5033 - val_mae: 2.8617
# Epoch 22/100
# 16/16 [==============================] - 0s 4ms/step - loss: 11.4013 - mae: 2.4894 - val_loss: 11.5254 - val_mae: 2.7868
# Epoch 23/100
# 16/16 [==============================] - 0s 5ms/step - loss: 10.9009 - mae: 2.4125 - val_loss: 10.9665 - val_mae: 2.6543
# Epoch 24/100
# 16/16 [==============================] - 0s 4ms/step - loss: 10.3450 - mae: 2.3382 - val_loss: 10.5395 - val_mae: 2.6966
# Epoch 25/100
# 16/16 [==============================] - 0s 5ms/step - loss: 9.9458 - mae: 2.2802 - val_loss: 10.1000 - val_mae: 2.5800
# Epoch 26/100
# 16/16 [==============================] - 0s 6ms/step - loss: 9.6134 - mae: 2.2149 - val_loss: 9.9360 - val_mae: 2.5229
# Epoch 27/100
# 16/16 [==============================] - 0s 4ms/step - loss: 9.3442 - mae: 2.1947 - val_loss: 10.0351 - val_mae: 2.4201
# Epoch 28/100
# 16/16 [==============================] - 0s 4ms/step - loss: 9.3829 - mae: 2.1686 - val_loss: 9.5204 - val_mae: 2.4422
# Epoch 29/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.9891 - mae: 2.1141 - val_loss: 9.6235 - val_mae: 2.5132
# Epoch 30/100
# 16/16 [==============================] - 0s 5ms/step - loss: 8.8723 - mae: 2.1330 - val_loss: 9.4391 - val_mae: 2.4582
# Epoch 31/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.6635 - mae: 2.0825 - val_loss: 9.5501 - val_mae: 2.3780
# Epoch 32/100
# 16/16 [==============================] - 0s 5ms/step - loss: 8.5731 - mae: 2.1127 - val_loss: 9.3506 - val_mae: 2.3638
# Epoch 33/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.5816 - mae: 2.0736 - val_loss: 9.2981 - val_mae: 2.4447
# Epoch 34/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.4390 - mae: 2.0728 - val_loss: 9.0918 - val_mae: 2.3777
# Epoch 35/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.1606 - mae: 2.0681 - val_loss: 9.6456 - val_mae: 2.3194
# Epoch 36/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.1853 - mae: 2.0407 - val_loss: 9.3585 - val_mae: 2.4216
# Epoch 37/100
# 16/16 [==============================] - 0s 5ms/step - loss: 8.1617 - mae: 2.0414 - val_loss: 9.3614 - val_mae: 2.4453
# Epoch 38/100
# 16/16 [==============================] - 0s 5ms/step - loss: 8.1261 - mae: 2.0329 - val_loss: 9.2793 - val_mae: 2.4192
# Epoch 39/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.8740 - mae: 2.0344 - val_loss: 9.0395 - val_mae: 2.3297
# Epoch 40/100
# 16/16 [==============================] - 0s 4ms/step - loss: 8.0332 - mae: 2.0218 - val_loss: 9.3013 - val_mae: 2.3030
# Epoch 41/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.8010 - mae: 2.0066 - val_loss: 9.2172 - val_mae: 2.3093
# Epoch 42/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.8469 - mae: 2.0436 - val_loss: 9.0918 - val_mae: 2.3933
# Epoch 43/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.7499 - mae: 1.9976 - val_loss: 8.9777 - val_mae: 2.3530
# Epoch 44/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.7921 - mae: 1.9952 - val_loss: 9.0769 - val_mae: 2.3685
# Epoch 45/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.6375 - mae: 1.9548 - val_loss: 9.1347 - val_mae: 2.4029
# Epoch 46/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.6129 - mae: 1.9745 - val_loss: 8.8908 - val_mae: 2.3510
# Epoch 47/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.5705 - mae: 1.9504 - val_loss: 8.9258 - val_mae: 2.3528
# Epoch 48/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.5073 - mae: 1.9657 - val_loss: 8.8108 - val_mae: 2.2989
# Epoch 49/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.4390 - mae: 1.9491 - val_loss: 8.8777 - val_mae: 2.3531
# Epoch 50/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.3168 - mae: 1.9247 - val_loss: 8.8543 - val_mae: 2.3022
# Epoch 51/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.2968 - mae: 1.9355 - val_loss: 9.0545 - val_mae: 2.2941
# Epoch 52/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.3936 - mae: 1.9613 - val_loss: 8.9780 - val_mae: 2.3610
# Epoch 53/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.3960 - mae: 1.9327 - val_loss: 8.9750 - val_mae: 2.3595
# Epoch 54/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.2115 - mae: 1.9137 - val_loss: 9.2730 - val_mae: 2.2709
# Epoch 55/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.1486 - mae: 1.9242 - val_loss: 8.9053 - val_mae: 2.3637
# Epoch 56/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.2565 - mae: 1.9127 - val_loss: 8.9346 - val_mae: 2.3661
# Epoch 57/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.1133 - mae: 1.8858 - val_loss: 9.0072 - val_mae: 2.3784
# Epoch 58/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.0291 - mae: 1.8898 - val_loss: 9.0192 - val_mae: 2.3641
# Epoch 59/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.0265 - mae: 1.8766 - val_loss: 9.4602 - val_mae: 2.3089
# Epoch 60/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.0616 - mae: 1.9263 - val_loss: 9.1283 - val_mae: 2.2928
# Epoch 61/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8966 - mae: 1.8907 - val_loss: 8.8835 - val_mae: 2.3055
# Epoch 62/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8989 - mae: 1.8320 - val_loss: 9.0049 - val_mae: 2.3528
# Epoch 63/100
# 16/16 [==============================] - 0s 4ms/step - loss: 7.1364 - mae: 1.8984 - val_loss: 8.9196 - val_mae: 2.2958
# Epoch 64/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.8151 - mae: 1.8680 - val_loss: 8.9207 - val_mae: 2.3264
# Epoch 65/100
# 16/16 [==============================] - 0s 5ms/step - loss: 7.0085 - mae: 1.8650 - val_loss: 8.9560 - val_mae: 2.3324
# Epoch 66/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.9356 - mae: 1.8565 - val_loss: 9.0307 - val_mae: 2.3757
# Epoch 67/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.9816 - mae: 1.8659 - val_loss: 9.1578 - val_mae: 2.4095
# Epoch 68/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.7563 - mae: 1.8741 - val_loss: 8.7993 - val_mae: 2.2683
# Epoch 69/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.9575 - mae: 1.8695 - val_loss: 8.7884 - val_mae: 2.3122
# Epoch 70/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.8118 - mae: 1.8496 - val_loss: 8.7787 - val_mae: 2.2783
# Epoch 71/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.8112 - mae: 1.8478 - val_loss: 8.8207 - val_mae: 2.2988
# Epoch 72/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.8161 - mae: 1.8478 - val_loss: 8.9407 - val_mae: 2.2422
# Epoch 73/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.7638 - mae: 1.8324 - val_loss: 9.0125 - val_mae: 2.3669
# Epoch 74/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6034 - mae: 1.8172 - val_loss: 9.1897 - val_mae: 2.3816
# Epoch 75/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.7031 - mae: 1.8493 - val_loss: 9.0542 - val_mae: 2.3431
# Epoch 76/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.7268 - mae: 1.8271 - val_loss: 9.0222 - val_mae: 2.3059
# Epoch 77/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.7045 - mae: 1.8335 - val_loss: 9.0240 - val_mae: 2.3400
# Epoch 78/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.6195 - mae: 1.8145 - val_loss: 8.9302 - val_mae: 2.3031
# Epoch 79/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.7605 - mae: 1.8518 - val_loss: 8.8074 - val_mae: 2.2939
# Epoch 80/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5795 - mae: 1.8154 - val_loss: 8.9213 - val_mae: 2.3250
# Epoch 81/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5029 - mae: 1.8152 - val_loss: 8.9030 - val_mae: 2.2934
# Epoch 82/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6289 - mae: 1.8349 - val_loss: 9.5057 - val_mae: 2.4573
# Epoch 83/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.6985 - mae: 1.8160 - val_loss: 8.9460 - val_mae: 2.3248
# Epoch 84/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5063 - mae: 1.8129 - val_loss: 9.1774 - val_mae: 2.3970
# Epoch 85/100
# 16/16 [==============================] - 0s 5ms/step - loss: 6.5089 - mae: 1.7894 - val_loss: 9.5096 - val_mae: 2.2706
# Epoch 86/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.3550 - mae: 1.8344 - val_loss: 9.0863 - val_mae: 2.3832
# Epoch 87/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5144 - mae: 1.8084 - val_loss: 9.1242 - val_mae: 2.3732
# Epoch 88/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5211 - mae: 1.7823 - val_loss: 9.3844 - val_mae: 2.4230
# Epoch 89/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4094 - mae: 1.7711 - val_loss: 9.6161 - val_mae: 2.4627
# Epoch 90/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4029 - mae: 1.7937 - val_loss: 8.8991 - val_mae: 2.2492
# Epoch 91/100
# 16/16 [==============================] - 0s 6ms/step - loss: 6.4515 - mae: 1.7989 - val_loss: 9.1185 - val_mae: 2.3299
# Epoch 92/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5164 - mae: 1.8162 - val_loss: 9.0770 - val_mae: 2.3025
# Epoch 93/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4426 - mae: 1.7805 - val_loss: 9.1557 - val_mae: 2.3043
# Epoch 94/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4554 - mae: 1.7787 - val_loss: 9.0746 - val_mae: 2.2889
# Epoch 95/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.3567 - mae: 1.7744 - val_loss: 9.2988 - val_mae: 2.2728
# Epoch 96/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.5090 - mae: 1.7847 - val_loss: 8.9937 - val_mae: 2.3225
# Epoch 97/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.3488 - mae: 1.7709 - val_loss: 9.2274 - val_mae: 2.3898
# Epoch 98/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.4738 - mae: 1.7891 - val_loss: 9.1172 - val_mae: 2.3566
# Epoch 99/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.3318 - mae: 1.7663 - val_loss: 9.0350 - val_mae: 2.3102
# Epoch 100/100
# 16/16 [==============================] - 0s 4ms/step - loss: 6.3597 - mae: 1.7729 - val_loss: 9.1858 - val_mae: 2.3229

# %% [markdown]
# ### 학습과정의 시각화 및 성능 테스트

# %%
hist = pd.DataFrame(history.history)
hist
# Out:
#           loss        mae    val_loss    val_mae
# 0   568.972900  22.637341  562.773499  22.477730
# 1   515.712463  21.476252  499.889374  21.110662
# 2   454.478271  20.091898  426.333649  19.417084
# 3   382.386475  18.355045  343.669189  17.283163
# 4   303.403381  16.189354  256.659821  14.696253
# ..         ...        ...         ...        ...
# 95    6.509040   1.784742    8.993686   2.322472
# 96    6.348794   1.770907    9.227351   2.389814
# 97    6.473790   1.789123    9.117173   2.356560
# 98    6.331779   1.766332    9.035028   2.310215
# 99    6.359674   1.772934    9.185776   2.322887
#
# [100 rows x 4 columns]

# %%
# 학습과정 시각화를 위한 정보 추출
loss = history.history['loss']
val_loss = history.history['val_loss']

mae = history.history['mae']
val_mae = history.history['val_mae']

# %%
# 차트의 x 축을 위한 epoch 정보 생성
epochs = range(1, len(loss)+1)

# %%
# loss 정보 시각화
plt.plot(epochs, loss, label='Training loss')
plt.plot(epochs, val_loss, label='Validation loss')
plt.title('Training and validation loss')
plt.ylim([0,20])
plt.legend()

plt.show()

# %%
# Mean Absolute Error 정보 시각화
plt.plot(epochs, mae, label='Training mae')
plt.plot(epochs, val_mae, label='Validation mae')
plt.title('Training and validation mae')
plt.xlim([1,100])
plt.ylim([0,5])
plt.legend()

plt.show()

# %%
# 테스트 데이터 셋을 통한 성능 측정
test_loss, test_mae = model.evaluate(x=test_dataset, y=test_labels)
# Out:
# 3/3 [==============================] - 0s 4ms/step - loss: 6.7950 - mae: 2.0517

# %%
# 테스트 데이터 셋의 정답과 모델의 예측값 분석을 위한 모델의 예측값 생성
test_predictions = model.predict(test_dataset).flatten()

# %%
# 테스트 데이터 셋의 정답과 모델의 예측값을 이용한 상관 관계 시각화
plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [MPG]')
plt.ylabel('Predictions [MPG]')
plt.axis('equal')
plt.axis('square')
plt.xlim([0, 50])
plt.ylim([0,50])
_ = plt.plot([-100, 100], [-100, 100])
